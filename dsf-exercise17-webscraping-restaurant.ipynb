# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
with open ("stan&co.html") as f:
    page = BeautifulSoup(f, "lxml")
#https://stan-co.nl/utrecht/

# %%
title = page.select("title")[0].get_text()
print(title)
# Out:
# STAN&CO Utrecht | Food, Drinks & Friends

# %%
address = page.select(".header-adres")[0].get_text()
print(address)
# Out:
# Adres
#
# Ganzenmarkt 16A
# 3512 GD Utrecht
# 030 - 233 45 35
# utrecht@stan-co.nl

# %%
hours = page.select(".openingstijden")[0].get_text()
print(hours)
# Out:
# Ma
# 11:00 tot 00:00
# Di/Wo
# 10:00 tot 00:00
# Do
# 10:00 tot 01:00
# Vrij/Za
# 10:00 tot 02:00
# Zo
# 12:00 tot 00:00

# %%
vacatures = page.select(".col-md-6")[0].get_text()
print(vacatures)
# Out:
# Stan&
#                                     Vacature BARTENDER - WAITER
# Don't you want to be part of this awesome team?
#
# Het drukke seizoen ligt voor de deur en daarom zijn wij opzoek naar gave nieuwe medewerkers! Je kunt zowel fulltime als parttime bij ons werken. We hebben een groot, hecht en divers team met goede skills. Je leert cocktails shaken, koffies met latte art maken en flairen op de vloer en achter de bar. Heb jij zin om met ons in het weekend te knallen en ga je wel lekker op die horeca vibe? Let us know!
# Enjoy the good life!
#
#
# Bekijk hier de vacature & solliciteer

# %%
menu = page.select("#menukaart")[0].get_text()
print(menu)
# Out:
# Menukaart
# Benieuwd naar wat onze keuken te bieden heeft? Bekijk hier onze actuele menukaart. Onze menukaart staat boordevol met mooie lokale producten en wisselt daarom ook een aantal keer per jaar. Het menu biedt gerechten uit diverse windstreken en specialiteiten van het seizoen.
#
#
#
#
# Lunch
# Soep
# Salades
# Starters
# Sweets
# Josper Grilled
# Barfood
# Wijn
# Longdrinks & cocktails
# High ...
#
#
#
#
#
# Lunch
#
#
#
#
#
#
#
#
#
#
#
# Muffuletta
# chorizo | mortadella | ham | olijven | mozzarella | paprika
#
#
#                                             8.5
#
#
#
# Bagel steak
# kappertjes | uiencompote | tonijn-miso mayonaise
#
#
#                                             9
#
#
#
# Bagel zalm
# slow-cooked | mierikswortel | venkel | biet
#
#
#                                             8.5
#
#
#
#
#
# Bagel hummus
# gerookte pompoen | avocado
#
#
#                                             8
#
#
#
# Shakshuka
# ...
